# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#1.Find the error in the following Python code: Answers : is missing
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#2.What will be the output of this code? Answers "" is missing in a=10

a = "10"
b = "5"
print(a + b)
# Out:
# 105

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
# Answer is : There is no variable set for return

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
#   Cell In[6], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
# The bug is distance before the numbers in the line statement & also in Print statement there is no need for lists
numbers = [1, 2, 3, 4]
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#5.Find the error in the following Python code:
print "Hello, World!"
# Out:
#   Cell In[24], line 2
#     print "Hello, World!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Open Bracket is missing in the Print Statement
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
# Only variable is set but no action & again the formula is not clear, becuase it cannot be divisible by zero
x = 5 / 1

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 #7.Find the error in the following Python code:name = "Alice"
#       2 age = 25
# ----> 3 print("Name: " + name + ", Age: " + age)
#
# NameError: name 'name' is not defined

# %%
# here str is not used for age  & also name is not defined in the program line
name = "Alice"
age = str(25)
print("Name: " + name + ", Age: " + age)
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
# Out:
#   Cell In[15], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#There is no else statement, the program is not properly looped.
#9. Find the error in the following Python code:
x = 10
if x == 5:
    print("x is 5")
else:
    print(" x is not equal to 5")
# Out:
#  x is not equal to 5

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
# Out:
#   Cell In[13], line 3
#     def greet(name)
#                    ^
# SyntaxError: expected ':'

# %%
# Inside Def : is expected
def greet(name):
    print("Hello, " + name)

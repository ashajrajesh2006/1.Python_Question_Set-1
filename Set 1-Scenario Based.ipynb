# %%
#user is eligible to vote based on their age.
age=int(input("enter the age:"))
if(age >= 18):
    print("Eligible to vote")
else:
    print("Not Eligible to vote")
# Out:
# enter the age: 17
# Not Eligible to vote

# %%
#Write logic to identify and return the largest number from a given list
lists=[56,67,13,87,90,18]
largest_number= max(lists)
print ("largest number", largest_number)
# Out:
# largest number 90

# %%
def largestnumber():
    lists=[56,67,13,87,90,18]
    largest_number= max(lists)
    print ("largest number", largest_number)

# %%
largestnumber()
# Out:
# largest number 90

# %%
#Write logic to identify and return the smallest number from a given list
lists=[56,67,13,87,90,18]
smallest_number= min(lists)
print ("smallest number", smallest_number)
# Out:
# smallest number 13

# %%
#Write logic to determine the bonus amount based on the given salary
name=input("enter the employee name:")
Id=int(input("enter the employee number:"))
s=int(input("enter the Salary($):"))
if(s >= 50000):
    bonus=((s *10)/100)
    bonus_salary = s+bonus
    print("Bonus Salary($):",bonus_salary)
else:
     print("No Bonus")
# Out:
# enter the employee name: Priya
# enter the employee number: 123456
# enter the Salary($): 56000
# Bonus Salary($): 61600.0

# %%
#Write logic to check whether a given number is even or odd.
i=int(input("enter the number:"))
if((i % 2) ==1):
    print("Number is Odd")
else:
    print("Number is Even")
# Out:
# enter the number: 7
# Number is Odd

# %%
#Write logic to take a word or sentence as input and produce its reversed version.
string = "Asha"
reversed_string = string[::-1]  # [-s[::-1] tells Python to take the entire string from start to end but in reverse order, stepping backwards with -1.]
print (reversed_string)
# Out:
# ahsA

# %%
#Write logic to check if a student has passed a subject by scoring at least 40 marks
name=input("enter the name:")
marks=int(input("enter the subject marks:"))
if(marks >= 40):
    print("passed")
else:
    print("failed")
# Out:
# enter the name: tina
# enter the subject marks: 35
# failed

# %%
#Write logic to calculate the final amount to be paid after applying the discount
name=input("enter the customer name:")
Id=int(input("enter the customer number:"))
s=int(input("enter the total order($):"))
if(s >= 100):
    discount=((s *20)/100)
    discount_order = s-discount
    print("Discounted amount($):",discount_order)
else:
     print("No Discounts")
# Out:
# enter the customer name: Srisha
# enter the customer number: 45678
# enter the total order($): 150
# Discounted amount($): 120.0

# %%
#logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.
name=input("enter the customer name:")
a=int(input("enter the amount:"))
if(a <= 1000):
